# %%
roll_no="1024160057"
L=[]
for digit in roll_no:
  L.append(int(digit)*10)
print(L)
L.append(80)
print(L)
L.insert(3,30)
print(L)
L.remove(10)
print(L)
removed=L.pop()
print("Removed Element: ",removed)
print(L)
L.sort()
print(L)
L.sort(reverse=True)
print(L)
print(L[:3])
print(L[-3:])
average=sum(L)/len(L)
print(average)
greater_than_avg=[x for x in L if x>average]
print(greater_than_avg)
# Out:
# [10, 0, 20, 40, 10, 60, 0, 0, 50, 70]
# [10, 0, 20, 40, 10, 60, 0, 0, 50, 70, 80]
# [10, 0, 20, 30, 40, 10, 60, 0, 0, 50, 70, 80]
# [0, 20, 30, 40, 10, 60, 0, 0, 50, 70, 80]
# Removed Element:  80
# [0, 20, 30, 40, 10, 60, 0, 0, 50, 70]
# [0, 0, 0, 10, 20, 30, 40, 50, 60, 70]
# [70, 60, 50, 40, 30, 20, 10, 0, 0, 0]
# [70, 60, 50]
# [0, 0, 0]
# 28.0
# [70, 60, 50, 40, 30]

# %%
roll_no="1024160057"
L=[]
for digit in roll_no:
  L.append(int(digit)*10)
print(L)
scores=tuple(L[:8])
print(scores)
highest=max(scores)
print(highest)
highest_index=scores.index(highest)
print(highest_index)
lowest=min(scores)
print(lowest)
lowest_index=scores.index(lowest)
print(lowest_index)
lowest_count=scores.count(lowest)
highest_count=scores.count(highest)
print(lowest_count,highest_count)
reverse_list=list(scores[::-1])
print(reverse_list)
score=int(input("Enter score: "))
if score in scores:
  print("Score found")
else:
  print("Score not found")
print("First Score:", first_score)
print("Second Score:", second_score)
print("Remaining Scores:", remaining_scores)
# Out:
# [10, 0, 20, 40, 10, 60, 0, 0, 50, 70]
# (10, 0, 20, 40, 10, 60, 0, 0)
# 60
# 5
# 0
# 1
# 3 1
# [0, 0, 60, 10, 40, 20, 0, 10]
# Enter score: 10
# Score found
# First Score: 10
# Second Score: 0
# Remaining Scores: [20, 40, 10, 60, 0, 0]

# %%
import random
from collections import Counter
random.seed(1024160057)
numbers = [random.randint(100, 900) for _ in range(100)]

print("Random numbers:")
print(numbers)

odd_numbers = [x for x in numbers if x % 2 != 0]

print("\nOdd numbers:")
print(odd_numbers)
print("Number of odd numbers:", len(odd_numbers))

even_numbers = [x for x in numbers if x % 2 == 0]

print("\nEven numbers:")
print(even_numbers)
print("Number of even numbers:", len(even_numbers))

def is_prime(n):
    if n < 2:
        return False

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False

    return True


prime_numbers = [x for x in numbers if is_prime(x)]

print("\nPrime numbers:")
print(prime_numbers)
print("Number of prime numbers:", len(prime_numbers))

frequency = Counter(numbers)

most_common_number, frequency_count = frequency.most_common(1)[0]

print("\nMost frequent number:", most_common_number)
print("Frequency:", frequency_count)
# Out:
# Random numbers:
# [668, 509, 682, 675, 503, 258, 841, 894, 239, 241, 491, 892, 188, 567, 521, 194, 688, 268, 607, 530, 339, 270, 645, 470, 262, 160, 699, 698, 366, 808, 894, 196, 140, 609, 674, 369, 129, 468, 111, 367, 718, 456, 584, 672, 142, 146, 205, 815, 299, 270, 690, 473, 494, 117, 468, 495, 706, 828, 420, 445, 898, 785, 529, 166, 634, 752, 272, 516, 141, 299, 401, 111, 236, 367, 309, 818, 201, 238, 681, 470, 782, 520, 707, 528, 201, 159, 790, 690, 215, 398, 295, 476, 651, 263, 859, 336, 600, 720, 505, 499]
#
# Odd numbers:
# [509, 675, 503, 841, 239, 241, 491, 567, 521, 607, 339, 645, 699, 609, 369, 129, 111, 367, 205, 815, 299, 473, 117, 495, 445, 785, 529, 141, 299, 401, 111, 367, 309, 201, 681, 707, 201, 159, 215, 295, 651, 263, 859, 505, 499]
# Number of odd numbers: 45
#
# Even numbers:
# [668, 682, 258, 894, 892, 188, 194, 688, 268, 530, 270, 470, 262, 160, 698, 366, 808, 894, 196, 140, 674, 468, 718, 456, 584, 672, 142, 146, 270, 690, 494, 468, 706, 828, 420, 898, 166, 634, 752, 272, 516, 236, 818, 238, 470, 782, 520, 528, 790, 690, 398, 476, 336, 600, 720]
# Number of even numbers: 55
#
# Prime numbers:
# [509, 503, 239, 241, 491, 521, 607, 367, 401, 367, 263, 859, 499]
# Number of prime numbers: 13
#
# Most frequent number: 894
# Frequency: 2

# %%
digits = [1, 0, 2, 4, 1, 6, 0, 0]
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print("Set A:", A)
print("Set B:", B)
union_set = A.union(B)
print("Union:", union_set)
intersection_set = A.intersection(B)
print("Intersection:", intersection_set)
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)
print("A - B:", A_minus_B)
print("B - A:", B_minus_A)
symmetric_difference = A.symmetric_difference(B)
print("Symmetric Difference:", symmetric_difference)
print("Is A subset of B?", A.issubset(B))
print("Is B superset of A?", B.issuperset(A))
X = int(input("Enter a value to remove from A: "))
A.discard(X)
print("Set A after discard:", A)
# Out:
# Set A: {0, 7, 42, 14, 28}
# Set B: {0, 36, 9, 18, 54}
# Union: {0, 36, 7, 9, 42, 14, 18, 54, 28}
# Intersection: {0}
# A - B: {42, 28, 14, 7}
# B - A: {9, 18, 36, 54}
# Symmetric Difference: {7, 9, 14, 18, 28, 36, 42, 54}
# Is A subset of B? False
# Is B superset of A? False
# Enter a value to remove from A: 7
# Set A after discard: {0, 42, 14, 28}

# %%
my_dict = {
    "name": "Divyanshi",
    "roll_no": "1024160057",
    "branch": "CSE",
    "age": 20,
    "city": "Jalandhar"
}
print("Original dictionary:")
print(my_dict)
my_dict["location"] = my_dict.pop("city")
print("\nAfter renaming city to location:")
print(my_dict)
cgpa = float(input("\nEnter your CGPA: "))
my_dict["cgpa"] = cgpa
print("After adding CGPA:")
print(my_dict)
my_dict["age"] += 1
print("\nAfter increasing age by 1:")
print(my_dict)
dict_pop = my_dict.copy()
removed_branch = dict_pop.pop("branch")
print("\nDictionary after deleting branch using pop():")
print(dict_pop)
print("Value returned by pop():", removed_branch)
dict_del = my_dict.copy()
del dict_del["branch"]
print("\nDictionary after deleting branch using del:")
print(dict_del)
print("\nKey-value pairs:")
for key, value in my_dict.items():
    print(f"{key} → {value}")
if "email" in my_dict:
    print("\nEmail:", my_dict["email"])
else:
    print("\nEmail key does not exist.")

friend_dict = {
    "name": "Tulika",
    "roll_no": "1024160110",
    "branch": "CSE",
    "age": 20,
    "city": "Delhi"
}

merged_dict = {**my_dict, **friend_dict}

print("\nMerged dictionary:")
print(merged_dict)

string_values = {
    key: value
    for key, value in my_dict.items()
    if isinstance(value, str)
}

print("\nOnly key-value pairs where value is a string:")
print(string_values)
# Out:
# Original dictionary:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'branch': 'CSE', 'age': 20, 'city': 'Jalandhar'}
#
# After renaming city to location:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'branch': 'CSE', 'age': 20, 'location': 'Jalandhar'}
#
# Enter your CGPA: 8.1
# After adding CGPA:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'branch': 'CSE', 'age': 20, 'location': 'Jalandhar', 'cgpa': 8.1}
#
# After increasing age by 1:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'branch': 'CSE', 'age': 21, 'location': 'Jalandhar', 'cgpa': 8.1}
#
# Dictionary after deleting branch using pop():
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'age': 21, 'location': 'Jalandhar', 'cgpa': 8.1}
# Value returned by pop(): CSE
#
# Dictionary after deleting branch using del:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'age': 21, 'location': 'Jalandhar', 'cgpa': 8.1}
#
# Key-value pairs:
# name → Divyanshi
# roll_no → 1024160057
# branch → CSE
# age → 21
# location → Jalandhar
# cgpa → 8.1
#
# Email key does not exist.
#
# Merged dictionary:
# {'name': 'Tulika', 'roll_no': '1024160110', 'branch': 'CSE', 'age': 20, 'location': 'Jalandhar', 'cgpa': 8.1, 'city': 'Delhi'}
#
# Only key-value pairs where value is a string:
# {'name': 'Divyanshi', 'roll_no': '1024160057', 'branch': 'CSE', 'location': 'Jalandhar'}
